# %%
from tqdm.notebook import tqdm

import matplotlib.pyplot as plt

import analysis
import catalog
import figures
import histograms

catalog.display_params_for_catalog()
tqdm.pandas()

# %% [markdown]
# ## Reading catalog

# %%
ESEC_avalanches = catalog.load("catalog/6_ESEC_avalanches_83.pickle")

ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 4] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 12] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 14] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 17] #Rien et Signal chelou
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 18] #Rien
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 35] #Rien
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 45] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 51] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 52] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 54] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 55] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 56] #RIEN sur premier signal
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 58] #RIEN sur premier signal
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 66] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 69] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 70] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 73] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 74] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 75] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 77] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 83] #RIEN
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 86] #RIEN

ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 7] #Signal chelou
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 15] #Signal chelou a check
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 16] #Signal chelou
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 25] #Signal chelou
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 31] #Signal chelou
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 34] #Signal chelou
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 61] #Signal chelou
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 64] #Signal chelou
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 71] #Signal chelou
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 76] #Signal chelou

ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 30] #Signal pas vu
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 79] #Signal pas vu

ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 1] #Mauvaise détection
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 13] #Mauvaise détection
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 19] #Mauvaise détection
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 33] #Mauvaise détection
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 44] #Mauvaise détection
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 59] #Mauvaise détection
ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 65] #Mauvaise détection

ESEC_avalanches = ESEC_avalanches[ESEC_avalanches["numero"] != 29] #Energie chelou
 
histograms.open_catalog(ESEC_avalanches, pos_number=0.15, xlim=50)

# %%
plt.figure(figsize=(10, 15), dpi=300)

events_to_keep = []

label1 = True
label2 = True

for event_index in tqdm(ESEC_avalanches["numero"], total=len(ESEC_avalanches)):
    print("-------------------------")
    print("Event numero", event_index)
    print("-------------------------")

    _, stream, _ = analysis.filter_stream(ESEC_avalanches, event_index, 0, freq_HP=9, freq_LP=0.5)

    print("Nombre de traces :", len(stream))

    analysis.methode_de_detection_pour_tous_les_evenements(ESEC_avalanches, stream, event_index, events_to_keep, label1, label2)

plt.xlabel(r"Volume ($\mathrm{m^3}$)", fontsize=14)
plt.ylabel("Distance de la station à l'avalanche (km)", fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.xscale("log")
plt.ylim(0, 600)
plt.margins(y=0)
# plt.legend(loc="lower right", fontsize=14)
figures.save(f"figures/all_events")
plt.show()
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# -------------------------
# Event numero 0
# -------------------------
# Nombre de traces : 51
# Work on trace 0
# The distance of the trace is 48.81039753705775
# Detection on trace 0
#
# Work on trace 1
# The distance of the trace is 73.09708038897358
# Detection on trace 1
#
# Work on trace 2
# The distance of the trace is 86.611602545445
# Detection on trace 2
#
# Work on trace 3
# The distance of the trace is 88.57297235980887
# Detection on trace 3
#
# Work on trace 4
# The distance of the trace is 105.78079018131146
# Detection on trace 4
#
# Work on trace 5
# The distance of the trace is 112.5201218265092
# Detection on trace 5
#
# Work on trace 6
# The distance of the trace is 116.36074938143248
# Detection on trace 6
#
# Work on trace 7
# The distance of the trace is 118.45240944598672
# Detection on trace 7
#
# Work on trace 8
# The distance of the trace is 123.48322344495705
# Detection on trace 8
#
# Work on trace 9
# ...

# %%
ESEC_avalanches = ESEC_avalanches.loc[events_to_keep]

histograms.open_catalog(ESEC_avalanches, 0.11, 50)

# %%
ESEC_avalanches.to_pickle("catalog/7_ESEC_avalanches_42.pickle")
